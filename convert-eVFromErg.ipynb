# %%
pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/38.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.7 MB ? eta -:--:--
#    ----- ---------------------------------- 5.0/38.7 MB 20.2 MB/s eta 0:00:02
#    ------------- -------------------------- 12.8/38.7 MB 26.8 MB/s eta 0:00:01
#    ------------------------ --------------- 23.6/38.7 MB 34.7 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.7 MB 43.0 MB/s eta 0:00:01
#    ---------------------------------------- 38.7/38.7 MB 38.5 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
"""After first lecture Victoria gave exercise to transfer the result in eV from 
Erg$$\Delta E \sim \frac{\hbar}{\Delta t} = \frac{10^{-27} Erg \cdot s}{10^{-8} s} = 10^{-19} Erg = \dots eV? \quad (1)$$"""

from scipy.constants import hbar, eV 
from scipy.constants import erg 


delta_t = 10e-8 
delta_E_joules = hbar / delta_t 
delta_E_eV = delta_E_joules / eV 

print(f"Resultado: {delta_E_eV:.3e} eV")
# Out:
# Resultado: 6.582e-09 eV
